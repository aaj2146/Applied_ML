# %%
% matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import load_iris

# %%
iris_dataset = load_iris()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
iris_dataset['data'], iris_dataset['target'], random_state=0)

# %%
fig, ax = plt.subplots(4,4, figsize = (15,15))
ax[0,0].set_ylabel('sepal length (cm)')
ax[1,0].set_ylabel('sepal width (cm)')
ax[2,0].set_ylabel('petal length (cm)')
ax[3,0].set_ylabel('petal width (cm)')

ax[3,0].set_xlabel('sepal length (cm)')
ax[3,1].set_xlabel('sepal width (cm)')
ax[3,2].set_xlabel('petal length (cm)')
ax[3,3].set_xlabel('petal width (cm)')

ax[0,0].hist(iris_dataset['data'][:,0],bins =20, ec =  'k')
ax[1,1].hist(iris_dataset['data'][:,1],bins =20, ec =  'k')
ax[2,2].hist(iris_dataset['data'][:,2],bins =20, ec =  'k')
ax[3,3].hist(iris_dataset['data'][:,3],bins =20, ec =  'k')




#ax[0,1].legend(numpoints=1)
ax[0,1].scatter(iris_dataset['data'][:,1],iris_dataset['data'][:,0], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[0,2].scatter(iris_dataset['data'][:,2],iris_dataset['data'][:,0], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[0,3].scatter(iris_dataset['data'][:,3],iris_dataset['data'][:,0], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])

ax[1,0].scatter(iris_dataset['data'][:,0],iris_dataset['data'][:,1], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[1,2].scatter(iris_dataset['data'][:,2],iris_dataset['data'][:,1], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[1,3].scatter(iris_dataset['data'][:,3],iris_dataset['data'][:,1], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])


ax[2,0].scatter(iris_dataset['data'][:,0],iris_dataset['data'][:,2], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[2,1].scatter(iris_dataset['data'][:,1],iris_dataset['data'][:,2], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[2,3].scatter(iris_dataset['data'][:,3],iris_dataset['data'][:,2], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])

ax[3,0].scatter(iris_dataset['data'][:,0],iris_dataset['data'][:,3], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[3,1].scatter(iris_dataset['data'][:,1],iris_dataset['data'][:,3], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[3,2].scatter(iris_dataset['data'][:,2],iris_dataset['data'][:,3], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])


from matplotlib.lines import Line2D
from matplotlib.patches import Circle

#line1 = 

custom_lines = [Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="b"),
                Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="r"),
                Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="g")]


#ax[0,1].legend(custom_lines, ['Cold', 'Medium', 'Hot'])

ax[0,1].legend(custom_lines, ['Setosa', 'Versicolor', 'Virginica'],loc='upper center', bbox_to_anchor=(1, 1.2),
          ncol=3, fancybox=True, shadow=True)

# %%
fig.savefig('task32.png',bbox='tight')

# %%
% matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import load_iris

iris_dataset = load_iris()

fig, ax = plt.subplots(4,4, figsize = (15,15))
ax[0,0].set_ylabel('sepal length (cm)')
ax[1,0].set_ylabel('sepal width (cm)')
ax[2,0].set_ylabel('petal length (cm)')
ax[3,0].set_ylabel('petal width (cm)')

ax[3,0].set_xlabel('sepal length (cm)')
ax[3,1].set_xlabel('sepal width (cm)')
ax[3,2].set_xlabel('petal length (cm)')
ax[3,3].set_xlabel('petal width (cm)')

ax[0,0].hist(iris_dataset['data'][:,0],bins =20, ec =  'k')
ax[1,1].hist(iris_dataset['data'][:,1],bins =20, ec =  'k')
ax[2,2].hist(iris_dataset['data'][:,2],bins =20, ec =  'k')
ax[3,3].hist(iris_dataset['data'][:,3],bins =20, ec =  'k')




#ax[0,1].legend(numpoints=1)
ax[0,1].scatter(iris_dataset['data'][:,1],iris_dataset['data'][:,0], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[0,2].scatter(iris_dataset['data'][:,2],iris_dataset['data'][:,0], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[0,3].scatter(iris_dataset['data'][:,3],iris_dataset['data'][:,0], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])

ax[1,0].scatter(iris_dataset['data'][:,0],iris_dataset['data'][:,1], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[1,2].scatter(iris_dataset['data'][:,2],iris_dataset['data'][:,1], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[1,3].scatter(iris_dataset['data'][:,3],iris_dataset['data'][:,1], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])


ax[2,0].scatter(iris_dataset['data'][:,0],iris_dataset['data'][:,2], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[2,1].scatter(iris_dataset['data'][:,1],iris_dataset['data'][:,2], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[2,3].scatter(iris_dataset['data'][:,3],iris_dataset['data'][:,2], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])

ax[3,0].scatter(iris_dataset['data'][:,0],iris_dataset['data'][:,3], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[3,1].scatter(iris_dataset['data'][:,1],iris_dataset['data'][:,3], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])
ax[3,2].scatter(iris_dataset['data'][:,2],iris_dataset['data'][:,3], c = iris_dataset['target'],cmap = 'brg', edgecolor = 'k',label= iris_dataset['target'])


from matplotlib.lines import Line2D
from matplotlib.patches import Circle

#line1 = 

custom_lines = [Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="b"),
                Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="r"),
                Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="g")]


#ax[0,1].legend(custom_lines, ['Cold', 'Medium', 'Hot'])

ax[0,1].legend(custom_lines, ['Setosa', 'Versicolor', 'Virginica'],loc='upper center', bbox_to_anchor=(1, 1.2),
          ncol=3, fancybox=True, shadow=True)

fig.savefig('task32.png',bbox='tight')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


data = pd.read_csv('task31.csv')




science = data.USS
hanging = data.Hang_s
yr = data.Year

y1ticks =['$15 billion', '$20 billion', '$25 billion', '$30 billion']
y2ticks =['4000 suicides', '6000 suicides', '8000 suicides', '10000 suicides']

#create x ticks
x_ticks = range(1999,2010)

fig = plt.figure(figsize=(16, 5)) 

#plt.figure(figsize=(16, 5))
ax = [0,0]
ax[0] = plt.gca()

line1 = ax[0].plot(yr,science, c='r', label = 'US Spending on Science',marker = 'o') 

ax[1] = ax[0].twinx()

line2 = ax[1].plot(yr,hanging, c='black', label = 'Hanging Suicides',marker='o') 
lines = ax[0].get_lines() + ax[1].get_lines()  
ax[0].legend(lines,[line.get_label() for line in lines], loc='lower center')
ax[0].set_ylabel('US Spending on Science',labelpad = 12)
ax[1].set_ylabel('Hanging Suicodes',rotation = -90,labelpad = 20)
ax[0].set_title('US Spending on science, space, and technology \n correlates with \n Suiceides by hanging, strangulation and suffocation \n Correlation: 99.79% (r = 0.99789126)', fontsize=12)

y1 = range(15,35,5)
ax[0].set_yticks(y1)
ax[0].set_yticklabels(y1ticks)

y2 = range(4000,12000,2000)
ax[1].set_yticks(y2)
ax[1].set_yticklabels(y2ticks)

ax[0].set_xticks(x_ticks)
plt.tight_layout()

plt.show()
fig.savefig('task31',bbox = 'tight')
