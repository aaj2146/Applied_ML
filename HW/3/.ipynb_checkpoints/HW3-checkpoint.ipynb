# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import fancyimpute as fi
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from datetime import datetime

# %%
d15 = pd.read_excel("2015 FE Guide-for DOE-Mobility Ventures only-OK to release-no-sales-4-27-2017Mercedesforpublic.xlsx")
d16 = pd.read_excel("2016 FE Guide for DOE-OK to release-no-sales-4-27-2017Mercedesforpublic.xlsx")
d17 = pd.read_excel("2017 FE Guide for DOE-release dates before 9-20-2017-no sales-9-19-2017MercedesCadillacforpublic.xlsx")

# %%
d18 = pd.read_excel("2018 FE Guide for DOE-release dates before 2-17-2018-no-sales-2-15-2018public.xlsx")

# %%
d18.shape
# Out:
# (1220, 162)

# %%
frames = [d15, d16, d17]
all_years_frame = [d15, d16, d17, d18]

d_all = pd.concat(all_years_frame)
d_train = pd.concat(frames)

# %%
d_train.shape
# Out:
# (3701, 162)

# %%
#Finding number of numerical categories
num_cols = d_train._get_numeric_data().columns

# %%
num_cols.shape
# Out:
# (86,)

# %%
d_all.shape
# Out:
# (4921, 162)

# %%
d_temp = d_all[['Model Year',
    'Index (Model Type Index)',
 'Range1 - Model Type Driving Range - Conventional Fuel',
 '2Dr Pass Vol',
 '4Dr Pass Vol',
 '4Dr Lugg Vol',
 'Htchbk Pass Vol',
 'Htchbk Lugg Vol',
 'Fuel2 Annual Fuel Cost - Alternative Fuel',
 'Carline Class',
 'Release Date',
 '$ You Save over 5 years (amount saved in fuel costs over 5 years - on label) ',
 
 'Mfr Name',
 'Division',
 'Verify Mfr Cd',
 '# Cyl',
 'Transmission',
 'Air Aspir Method',
 'Trans',
 '# Gears',
 'Lockup Torque Converter',
 'Trans Creeper Gear',
 'Drive Sys',
 'Max Ethanol % - Gasoline',
 'Fuel Usage  - Conventional Fuel',
 'Gas Guzzler Exempt (Where Truck = 1975 NHTSA truck definition)',
 ' Range2 - Alt Fuel Model Typ Driving Range - Alternative Fuel',
 ' Fuel2 Usage - Alternative Fuel',
 'Exhaust Valves Per Cyl',
 'Car/Truck Category - Cash for Clunkers Bill.',
 'Unique Label?',
 'Label Recalc?',
 'Cyl Deact?',
 'Var Valve Timing?',
 'Var Valve Lift?',
 'Fuel Metering Sys Cd',
 'Off Board Charge Capable (Y or N)',
 'Camless Valvetrain (Y or N)',
 'Stop/Start System (Engine Management System) Code']]

# %%
d_tr = d_train[['Model Year',
    'Index (Model Type Index)',
 'Range1 - Model Type Driving Range - Conventional Fuel',
 '2Dr Pass Vol',
 '4Dr Pass Vol',
 '4Dr Lugg Vol',
 'Htchbk Pass Vol',
 'Htchbk Lugg Vol',
 'Fuel2 Annual Fuel Cost - Alternative Fuel',
 'Carline Class',
 'Release Date',
 '$ You Save over 5 years (amount saved in fuel costs over 5 years - on label) ',
 
 'Mfr Name',
 'Division',
 'Verify Mfr Cd',
 '# Cyl',
 'Transmission',
 'Air Aspir Method',
 'Trans',
 '# Gears',
 'Lockup Torque Converter',
 'Trans Creeper Gear',
 'Drive Sys',
 'Max Ethanol % - Gasoline',
 'Fuel Usage  - Conventional Fuel',
 'Gas Guzzler Exempt (Where Truck = 1975 NHTSA truck definition)',
 ' Range2 - Alt Fuel Model Typ Driving Range - Alternative Fuel',
 ' Fuel2 Usage - Alternative Fuel',
 'Exhaust Valves Per Cyl',
 'Car/Truck Category - Cash for Clunkers Bill.',
 'Unique Label?',
 'Label Recalc?',
 'Cyl Deact?',
 'Var Valve Timing?',
 'Var Valve Lift?',
 'Fuel Metering Sys Cd',
 'Off Board Charge Capable (Y or N)',
 'Camless Valvetrain (Y or N)',
 'Stop/Start System (Engine Management System) Code']]

# %%
d_tr.shape
d_tr_cat = d_tr.select_dtypes(include = ['object'])
d_tr_num = d_tr.select_dtypes(exclude = ['object'])

# %%
d_tr_num = d_tr_num.drop(['Model Year','Carline Class','# Cyl','# Gears',
                      'Max Ethanol % - Gasoline','Exhaust Valves Per Cyl','Release Date' ],axis = 1)

# %%
col_list = ['Model Year','Carline Class','# Cyl','# Gears',
                      'Max Ethanol % - Gasoline','Exhaust Valves Per Cyl']

# %%
for i in col_list:
    d_tr_cat[i]=d_tr[i]

# %%
d_tr_cat.head()
# Out:
#   Range1 - Model Type Driving Range - Conventional Fuel      Mfr Name  \
# 0                                                NaN        FCA Italy
# 1                                                NaN     aston martin
# 2                                                NaN     aston martin
# 3                                                NaN     aston martin
# 4                                                NaN     aston martin
#
#                    Division Verify Mfr Cd Transmission Air Aspir Method Trans  \
# 0                Alfa Romeo           FTG    Auto(AM6)               TC    AM
# 1  Aston Martin Lagonda Ltd           ASX    Auto(AM7)              NaN    AM
# 2  Aston Martin Lagonda Ltd           ASX    Auto(AM7)              NaN    AM
# 3  Aston Martin Lagonda Ltd           ASX   Manual(M6)              NaN     M
# 4  Aston Martin Lagonda Ltd           ASX    Auto(AM7)              NaN    AM
#
# ...

# %%
d_tr_num.dtypes
# Out:
# Index (Model Type Index)                                                           int64
# 2Dr Pass Vol                                                                     float64
# 4Dr Pass Vol                                                                     float64
# 4Dr Lugg Vol                                                                     float64
# Htchbk Pass Vol                                                                  float64
# Htchbk Lugg Vol                                                                  float64
# Fuel2 Annual Fuel Cost - Alternative Fuel                                        float64
# $ You Save over 5 years (amount saved in fuel costs over 5 years - on label)     float64
# dtype: object

# %%
d_tr_num = d_tr_num.reset_index(drop=True)

# %%
#d_tr_num = d_tr_num.drop(["Release Date"], axis = 1)

# %%
datetime.strptime(str(d_tr_num['Release Date'][0]).split(".")[0], '%Y-%m-%d %H:%M:%S').date().toordinal()
# Out:
# 735414

# %%
# for i in range(len(d_tr_num['Release Date'])):
#     d_tr_num['Release Date'][i] = datetime.strptime(str(d_tr_num['Release Date'][i]).split(".")[0], '%Y-%m-%d %H:%M:%S').date().toordinal()
#     print(i)

# %%
d_tr_num

# %%
from sklearn.preprocessing import Imputer

imp_num = Imputer(strategy = 'median').fit(d_tr_num)

# %%
X_tr_imp = imp_num.transform(d_tr_num)

# %%
X_tr_num = pd.DataFrame(X_tr_imp, columns=d_tr_num.columns)

# %%
X_tr_num
# Out:
#       Index (Model Type Index)  2Dr Pass Vol  4Dr Pass Vol  4Dr Lugg Vol  \
# 0                        264.0          83.0          98.0          14.0
# 1                          8.0          83.0          98.0          14.0
# 2                          4.0          83.0          98.0          14.0
# 3                          1.0          83.0          98.0          14.0
# 4                          5.0          83.0          98.0          14.0
# 5                          2.0          83.0          98.0          14.0
# 6                          6.0          83.0          98.0          14.0
# 7                          3.0          83.0          98.0          14.0
# 8                         27.0          83.0          98.0          14.0
# 9                         29.0          83.0          98.0          14.0
# 10                        35.0          83.0          98.0          14.0
# 11                        33.0          83.0          98.0          14.0
# ...

# %%
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()

scaler.fit(X_tr_num)

X_tr_num_sc = scaler.transform(X_tr_num)

# %%
X_tr_num_sc = pd.DataFrame(X_tr_num_sc, columns=X_tr_num.columns)

# %%
X_tr_num_sc #train data numerical scaled
# Out:
#       Index (Model Type Index)  2Dr Pass Vol  4Dr Pass Vol  4Dr Lugg Vol  \
# 0                     0.249234      0.014368     -0.050836     -0.173528
# 1                    -0.907082      0.014368     -0.050836     -0.173528
# 2                    -0.925150      0.014368     -0.050836     -0.173528
# 3                    -0.938700      0.014368     -0.050836     -0.173528
# 4                    -0.920633      0.014368     -0.050836     -0.173528
# 5                    -0.934184      0.014368     -0.050836     -0.173528
# 6                    -0.916116      0.014368     -0.050836     -0.173528
# 7                    -0.929667      0.014368     -0.050836     -0.173528
# 8                    -0.821262      0.014368     -0.050836     -0.173528
# 9                    -0.812228      0.014368     -0.050836     -0.173528
# 10                   -0.785127      0.014368     -0.050836     -0.173528
# 11                   -0.794161      0.014368     -0.050836     -0.173528
# ...

# %%
d_tr_cat.head()
# Out:
#   Range1 - Model Type Driving Range - Conventional Fuel      Mfr Name  \
# 0                                                400        FCA Italy
# 1                                                400     aston martin
# 2                                                400     aston martin
# 3                                                400     aston martin
# 4                                                400     aston martin
#
#                    Division Verify Mfr Cd Transmission Air Aspir Method Trans  \
# 0                Alfa Romeo           FTG    Auto(AM6)               TC    AM
# 1  Aston Martin Lagonda Ltd           ASX    Auto(AM7)               TC    AM
# 2  Aston Martin Lagonda Ltd           ASX    Auto(AM7)               TC    AM
# 3  Aston Martin Lagonda Ltd           ASX   Manual(M6)               TC     M
# 4  Aston Martin Lagonda Ltd           ASX    Auto(AM7)               TC    AM
#
# ...

# %%
d_tr_cat = d_tr_cat.apply(lambda x:x.fillna(x.value_counts().index[0]))

# %%
d_tr_cat.isna().any()
# Out:
# Range1 - Model Type Driving Range - Conventional Fuel             False
# Mfr Name                                                          False
# Division                                                          False
# Verify Mfr Cd                                                     False
# Transmission                                                      False
# Air Aspir Method                                                  False
# Trans                                                             False
# Lockup Torque Converter                                           False
# Trans Creeper Gear                                                False
# Drive Sys                                                         False
# Fuel Usage  - Conventional Fuel                                   False
# Gas Guzzler Exempt (Where Truck = 1975 NHTSA truck definition)    False
#  Range2 - Alt Fuel Model Typ Driving Range - Alternative Fuel     False
# ...

# %%
d_tr_cat.isnull().any()
# Out:
# Range1 - Model Type Driving Range - Conventional Fuel             False
# Mfr Name                                                          False
# Division                                                          False
# Verify Mfr Cd                                                     False
# Transmission                                                      False
# Air Aspir Method                                                  False
# Trans                                                             False
# Lockup Torque Converter                                           False
# Trans Creeper Gear                                                False
# Drive Sys                                                         False
# Fuel Usage  - Conventional Fuel                                   False
# Gas Guzzler Exempt (Where Truck = 1975 NHTSA truck definition)    False
#  Range2 - Alt Fuel Model Typ Driving Range - Alternative Fuel     False
# ...

# %%
d_tr_cat_dummied = pd.get_dummies(d_tr_cat, columns = list(d_tr_cat))

# %%
d_tr_cat_dummied.shape
# Out:
# (3701, 375)

# %%
num_all = all_dat.select_dtypes(exclude = ['object'])

# %%
num_tr = np.where(num_all['Model'])
# Out:
# Index (Model Type Index)                                                                  int64
# 2Dr Pass Vol                                                                            float64
# 4Dr Pass Vol                                                                            float64
# 4Dr Lugg Vol                                                                            float64
# Htchbk Pass Vol                                                                         float64
# Htchbk Lugg Vol                                                                         float64
# Fuel2 Annual Fuel Cost - Alternative Fuel                                               float64
# Carline Class                                                                             int64
# Release Date                                                                     datetime64[ns]
# $ You Save over 5 years (amount saved in fuel costs over 5 years - on label)            float64
# ...

# %%
y_tr = d_train['Comb Unrd Adj FE - Conventional Fuel']
y_te = d18['Comb Unrd Adj FE - Conventional Fuel']

# %%
X_tr = d_train.drop(["Comb Unrd Adj FE - Conventional Fuel"], axis=1)

# %%
X_te = d18.drop(["Comb Unrd Adj FE - Conventional Fuel"], axis=1)

# %%
X_tr.shape
# Out:
# (3701, 161)

# %%
X_te.shape
# Out:
# (1220, 161)

# %% [markdown]
# # Now we check the distribution of the output

# %%
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
#gaussian_numbers = np.random.randn(1000)
plt.hist(y_tr, bins=50)
plt.title("Output mpg Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
#plt.boxplot(y_train)
fig = plt.gcf()

# %%
plt.boxplot(y_tr)
plt.title("Output mpg Boxplot")
plt.xlabel("Value")
plt.ylabel("Frequency")
fig = plt.gcf()

# %%
list(X_tr)
# Out:
# ['Model Year',
#  'Mfr Name',
#  'Division',
#  'Carline',
#  'Verify Mfr Cd',
#  'Index (Model Type Index)',
#  'Eng Displ',
#  '# Cyl',
#  'Transmission',
#  'City FE (Guide) - Conventional Fuel',
#  'Hwy FE (Guide) - Conventional Fuel',
#  'Comb FE (Guide) - Conventional Fuel',
#  'City Unadj FE - Conventional Fuel',
#  'Hwy Unadj FE - Conventional Fuel',
#  'Comb Unadj FE - Conventional Fuel',
#  'City Unrd Adj FE - Conventional Fuel',
#  'Hwy Unrd Adj FE - Conventional Fuel',
#  'Guzzler? ',
#  'Air Aspir Method',
#  'Air Aspiration Method Desc',
#  'Trans',
#  'Trans Desc',
#  'Trans, Other',
#  '# Gears',
#  'Lockup Torque Converter',
#  'Trans Creeper Gear',
#  'Drive Sys',
#  'Drive Desc',
#  'Max Ethanol % - Gasoline',
#  'Max Biodiesel %',
#  'Range1 - Model Type Driving Range - Conventional Fuel',
#  'Fuel Usage  - Conventional Fuel',
#  'Fuel Usage Desc - Conventional Fuel',
#  'Fuel Unit - Conventional Fuel',
#  'Fuel Unit Desc - Conventional Fuel',
# ...

# %%
X_tr_temp = X_tr[['Verify Mfr Cd',
'Intake Valves Per Cyl',
'Eng Displ',
'Trans',
'# Gears',
'Max Ethanol % - Gasoline',
'Drive Sys',
'Fuel Usage  - Conventional Fuel']]

# %%
X_te_temp = X_te[ ['Verify Mfr Cd',
'Intake Valves Per Cyl',
'Eng Displ',
'Trans',
'# Gears',
'Max Ethanol % - Gasoline',
'Drive Sys',
'Fuel Usage  - Conventional Fuel']]

# %%
X_tr_temp.shape
# Out:
# (3701, 8)

# %%
#X_tr_temp.select_dtypes(include=["number","bool_","object_","float_","int_"])

# %%
X_tr_cat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-dabbee365783> in <module>()
# ----> 1 X_tr_cat
#
# NameError: name 'X_tr_cat' is not defined

# %%
#Imputing the Nan
# import fancyimpute
# mice = fancyimpute.MICE(verbose=0)
# X_tr_num_imp = mice.complete(X_tr_num)
# X_te_num_imp = mice.complete(X_te_num)
X_tr_temp.fillna("",inplace=True)
X_te_temp.fillna("",inplace=True)
# Out:
# /home/adi/.local/lib/python3.5/site-packages/pandas/core/frame.py:3035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
X_te_num_imp.shape

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_tr_num_imp)

X_tr_num_sc = scaler.transform(X_tr_num_imp)

# %%
X_te_num_sc = scaler.transform(X_te_num_imp)

# %%
#Scaling all the columns



#pd.concat([df1, df4], axis=1, join_axes=[df1.index])
X_tr_num_imp = pd.DataFrame(X_tr_num_imp)
X_te_num_imp = pd.DataFrame(X_te_num_imp)

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_tr_num_knn)

X_tr_num_sc = scaler.transform(X_tr_num_knn)

X_te_num_sc = scaler.transform(X_te_num_knn)



X_tr_comb2 = pd.concat([X_tr_num_imp, X_tr_cat], axis=0, join_axes=[ X_tr_cat.index])
X_te_comb2 = pd.concat([X_te_num_imp, X_te_cat], axis=0)

#X_tr_comb = X_tr_cat.append(X_tr_num_imp)
#X_te_comb = pd.concat([X_te_num_imp, X_te_cat], axis=1, join_axes=[X_te_num_imp.index])

# %%
        
        

#Scaling data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_tr_num_knn)

X_tr_num_sc = scaler.transform(X_tr_num_knn)

X_te_num_sc = scaler.transform(X_te_num_knn)

# %%
X_tr_num

# %%
#Scaling the data

from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_tr_temp, y_train, random_state=0)

scaler = StandardScaler()
df[['x','z']] = mms.fit_transform(df[['x','z']])

scaler.fit(X_train[['GHG Rating (1-10 rating on Label)', 'Intake Valves Per Cyl','# Cyl','# Gears','Max Ethanol % - Gasoline']])

X_train_scaled = scaler.transform(X_train)

ridge = Ridge().fit(X_train_scaled, y_train)

X_test_scaled = scaler.transform(X_test)

ridge.score(X_test_scaled, y_test)

# %%
X_temp2 = pd.get_dummies(X_temp1)

# %%
X_temp2.shape

# %%
X_test_main = pd.get_dummies(X_t_test)

# %%
X_temp2.shape

# %%
X_test_main.shape

# %%
missing_cols = set( X_temp2.columns ) - set( X_test_main.columns )
# Add a missing column in test set with default value equal to 0
for c in missing_cols:
    X_test_main[c] = 0
# Ensure the order of column in the test set is in the same order than in train set
X_test_main2 = X_test_main[X_temp2.columns]

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split

# %%
X_test_main2.shape

# %%
lr = Ridge()

# %%
y_train.shape

# %%
X_temp2['y'] = y_train

# %%
X_temp2.shape

# %%
import numpy as np
X_lin = X_temp2.dropna() 
y_tr = X_lin['y']

# %%
X_lin2 = X_lin.drop(["y"], axis=1)

# %%
X_lin2.shape

# %%
list(X_lin2)

# %%
from sklearn.model_selection import train_test_split, cross_val_score
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_lin2, y_tr, random_state = 0)
lr.fit(X_train2,y_train2)

# %%
X_train2.shape

# %%
X_test_main2.fillna(0,inplace=True) 
#y_test_main.fillna(0, inplace=True)

# %%
X_test_main3 = X_test_main.drop(["y"], axis=1)

# %%
lr.score(X_test_main2, y_test_main)

# %%
np.mean(cross_val_score(Ridge(), X_test_main2, y_test_main, cv=10))

# %%
X_test_main2.head

# %%
X_train2.head

# %%
.drop(['City Unadj FE - Conventional Fuel','Descriptor - Model Type (40 Char or less)',
       'Release Date'
       'Hwy Unadj FE - Conventional Fuel', 'Mfr Name',
       'Comb Unadj FE - Conventional Fuel', 'Mfr Name','City Unrd Adj FE - Conventional Fuel', 
       'City FE (Guide) - Conventional Fuel','Hwy FE (Guide) - Conventional Fuel', 
       'Comb FE (Guide) - Conventional Fuel', 'Carline',
                                                         'Hwy Unrd Adj FE - Conventional Fuel','Annual Fuel1 Cost - Conventional Fuel',
                                                         'EPA Calculated Annual Fuel Cost - Conventional Fuel -----  Annual fuel cost error. Please revise Verify. ',
                                                         'EPA FE Label Dataset ID','$ You Save over 5 years (amount saved in fuel costs over 5 years - on label) ',
                                                         '$ You Spend over 5 years (increased amount spent in fuel costs over 5 years - on label) ',
                                                         'City CO2 Rounded Adjusted','Hwy CO2 Rounded Adjusted','Comb CO2 Rounded Adjusted (as shown on FE Label)',
                                                         'Guzzler? ', 'Gas Guzzler Exempt (Where Truck = 1975 NHTSA truck definition)',
                                                         'Gas Guzzler Exempt Desc (Where Truck = 1975 NHTSA truck definition)',
                                                        'City2 FE (Guide) - Alternative Fuel','Hwy2 Fuel FE (Guide) - Alternative Fuel',
                                                        'Comb2 Fuel FE (Guide) - Alternative Fuel',
                                                       'City2 Unadj FE - Alternative Fuel', 'Hwy2 Unadj FE - Alternative Fuel',
                                                       'Comb2 Unadj FE - Alternative Fuel',
                                                       'City2 Unrd Adj FE - Alternative Fuel',
                                                       'Hwy2 Unrd Adj FE - Alternative Fuel',
                                                        'Cmb2 Unrd Adj FE - Alternative Fuel', 'Index (Model Type Index)',
                                                        'City CO2 Rounded Adjusted - Fuel2', 'Hwy CO2 Rounded Adjusted - Fuel2',
                                                       'Comb CO2 Rounded Adjusted - Fuel2',
                                                       'Fuel2 EPA Calculated Annual Fuel Cost - Alternative Fuel',
                                                        '#2 Smog Rating Test Group', 'MFR Calculated Gas Guzzler MPG ',
                                                        '#1 Smog Rating Test Group', 'GHG 1-10 rating on Ethanol (EPA Determined)',
                                                         'Model Type Desc (MFR entered)',
                                                        'Var Valve Lift Desc','Comments - Mfr Eng Cnfg','Var Valve Timing Desc',
                                                        'Range1 - Model Type Driving Range - Conventional Fuel',
                                                         ' Range2 - Alt Fuel Model Typ Driving Range - Alternative Fuel',
                                                         'Rated Motor Gen Power (kW)',
       'FE Rating (1-10 rating on Label)','GHG Rating (1-10 rating on Label)',
      '#1 Mfr Smog Rating (Mfr Smog 1-10 Rating on Label for Test Group 1)'], axis=1)
